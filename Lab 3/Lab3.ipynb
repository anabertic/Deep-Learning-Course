# %%
import os
import numpy as np
from collections import Counter

class Dataset():

    def __init__(self, batch_size=32, sequence_length=30):
        self.batch_size = batch_size
        self.sequence_length = sequence_length
        self.current_batch_index = 0

    def preprocess(self, input_file):
        with open(input_file, "r") as f:
            data = f.read()

        # count and sort most frequent characters
        cntr = Counter(data)
        self.sorted_chars = sorted(cntr.keys(), key=cntr.get, reverse=True)

        # self.sorted chars contains just the characters ordered descending by frequency
        self.char2id = dict(zip(self.sorted_chars, range(len(self.sorted_chars)))) 
        # reverse the mapping
        self.id2char = {k:v for v,k in self.char2id.items()}
        # convert the data to ids
        self.x = np.array(list(map(self.char2id.get, data)))

    def encode(self, sequence):
        # returns the sequence encoded as integers
        return np.array(list(map(self.char2id.get, sequence)))

    def decode(self, encoded_sequence):
        # returns the sequence decoded as letters
        return np.array(list(map(self.id2char.get, encoded_sequence)))
    
    def decode_str(self, encoded_sequence):
        # returns the sequence decoded as string
        return "".join(self.decode(encoded_sequence))

    def create_minibatches(self):
        # shift data
        shifted_x = self.x[:-1]
        shifted_y = self.x[1:]
        # batch shape and total size
        batch_shape = (self.batch_size, self.sequence_length)
        step = self.batch_size * self.sequence_length

        self.num_batches = int(len(shifted_x) / step) 
        self.batches = []

        for batch_index in range(self.num_batches):
            batch_start_pos = batch_index * step
            batch_end_pos = batch_start_pos + step

            batch_x = np.array(shifted_x[batch_start_pos:batch_end_pos]).reshape(batch_shape)
            batch_y = np.array(shifted_y[batch_start_pos:batch_end_pos]).reshape(batch_shape)
            self.batches.append((batch_x, batch_y))

    def minibatch_generator(self):
        for epoch, (batch_x, batch_y) in enumerate(self.batches):
            new_epoch = epoch == 0
            yield new_epoch, batch_x, batch_y
            
    def next_minibatch(self):
        new_epoch = self.current_batch_index == 0
        batch_x, batch_y = self.batches[self.current_batch_index]
        self.current_batch_index += 1

        if self.current_batch_index >= self.num_batches:
            self.current_batch_index = 0

        return new_epoch, batch_x, batch_y

# %%
from sklearn.metrics import log_loss

def softmax(value):
    max_value = np.max(value, axis=2)
    max_value = max_value[:, :, np.newaxis] # Broadcast it manually
    exp = np.exp(value - max_value)
    return exp / np.sum(exp, axis=2, keepdims=True)

class SimpleRNN:

    def __init__(self, hidden_size, sequence_length, vocab_size, learning_rate):
        self.hidden_size = hidden_size
        self.sequence_length = sequence_length
        self.vocab_size = vocab_size
        self.learning_rate = learning_rate
        
        hidden_xavier_scale = 1.0 / np.sqrt(hidden_size)
        self.U = np.random.normal(size=[vocab_size, hidden_size], scale=hidden_xavier_scale) # ... input projection
        self.W = np.random.normal(size=[hidden_size, hidden_size], scale=hidden_xavier_scale) # ... hidden-to-hidden projection
        self.b = np.zeros([1, hidden_size]) # ... input bias

        self.V = np.random.normal(size=[hidden_size, vocab_size], scale=1.0 / np.sqrt(vocab_size)) # ... output projection
        self.c = np.zeros([1, vocab_size]) # ... output bias

        # memory of past gradients - rolling sum of squares for Adagrad
        self.memory_U, self.memory_W, self.memory_V = np.zeros_like(self.U), np.zeros_like(self.W), np.zeros_like(self.V)
        self.memory_b, self.memory_c = np.zeros_like(self.b), np.zeros_like(self.c)

    def rnn_step_forward(self, x, h_prev, U=None, W=None, b=None):
        # A single time step forward of a recurrent neural network with a 
        # hyperbolic tangent nonlinearity.

        # x - input data (minibatch size x input dimension)
        # h_prev - previous hidden state (minibatch size x hidden size)
        # U - input projection matrix (input dimension x hidden size)
        # W - hidden to hidden projection matrix (hidden size x hidden size)
        # b - bias of shape (hidden size x 1)
        
        # Extract values if given
        U = self.U if U is None else U
        W = self.W if W is None else W
        b = self.b if b is None else b

        h_current = np.tanh(np.dot(h_prev, W) + np.dot(x, U) + b)
        cache = (h_current, h_prev, x)
        return h_current, cache

    def rnn_forward(self, x, h0, U=None, W=None, b=None):
        # Full unroll forward of the recurrent neural network with a 
        # hyperbolic tangent nonlinearity

        # x - input data for the whole time-series (minibatch size x sequence_length x input dimension)
        # h0 - initial hidden state (minibatch size x hidden size)
        # U - input projection matrix (input dimension x hidden size)
        # W - hidden to hidden projection matrix (hidden size x hidden size)
        # b - bias of shape (hidden size x 1)
        
        # Extract values if given
        U = self.U if U is None else U
        W = self.W if W is None else W
        b = self.b if b is None else b

        h, cache = [h0], []
        sequences = x.transpose(1, 0, 2)
        
        for sequence in sequences:
            h_current, cache_current = self.rnn_step_forward(sequence, h[-1], U, W, b)
            cache.append(cache_current)
            h.append(h_current)
        
        # Skip initial hidden state
        h = np.array(h[1:]).transpose(1, 0, 2)

        # return the hidden states for the whole time series (T+1) and a tuple of values needed for the backward step
        return h, cache

    def rnn_step_backward(self, grad_next, cache):
        # A single time step backward of a recurrent neural network with a 
        # hyperbolic tangent nonlinearity.

        # grad_next - upstream gradient of the loss with respect to the next hidden state and current output
        # cache - cached information from the forward pass
        h_current, h_prev, x = cache

        # compute and return gradients with respect to each parameter
        da = grad_next * (1 - h_current**2)
        dh_prev = np.dot(da, self.W.T)
        dU = np.dot(x.T, da) / grad_next.shape[0]
        dW = np.dot(h_prev.T, da) / grad_next.shape[0]
        db = np.sum(da, axis=0) / grad_next.shape[0]

        return dh_prev, dU, dW, db

    def rnn_backward(self, dh, cache):
        # Full unroll forward of the recurrent neural network with a 
        # hyperbolic tangent nonlinearity
        
        dU, dW, db = np.zeros_like(self.U), np.zeros_like(self.W), np.zeros_like(self.b)

        # compute and return gradients with respect to each parameter
        # for the whole time series.
        # Why are we not computing the gradient with respect to inputs (x)?
        dh = dh.transpose(1, 0, 2)

        dh_prev = np.zeros_like(dh[-1])
        for dh_current, cache_current in reversed(list(zip(dh, cache))):
            dh_prev, dU_current, dW_current, db_current = self.rnn_step_backward(dh_current + dh_prev, cache_current)
            dU += dU_current
            dW += dW_current
            db += db_current

        return dU, dW, db

    def output(self, h, V=None, c=None):
        # Calculate the output probabilities of the network
        # Extract values if given
        V = self.V if V is None else V
        c = self.c if c is None else c
        logits = np.dot(h, V) + c
        return softmax(logits)

    def output_loss_and_grads(self, h, y, V=None, c=None):
        # Calculate the loss of the network for each of the outputs
        
        # h - hidden states of the network for each timestep. 
        #     the dimensionality of h is (batch size x sequence length x hidden size (the initial state is irrelevant for the output)
        # V - the output projection matrix of dimension hidden size x vocabulary size
        # c - the output bias of dimension vocabulary size x 1
        # y - the true class distribution - a tensor of dimension batch_size x sequence_length x vocabulary size

        # Extract values if given
        V = self.V if V is None else V
        c = self.c if c is None else c

        batch_size = h.shape[0]
        y_out = self.output(h, V, c)

        log_loss_ = log_loss(y.reshape(-1, self.vocab_size), y_out.reshape(-1, self.vocab_size))
        loss = log_loss_ * self.sequence_length  # Since it computes average cross_entropy loss
        d_out = y_out - y
        
        dh, dV, dc = [], np.zeros_like(V), np.zeros_like(c)
        
        for d_out_current, h_current in zip(d_out.transpose(1, 0, 2), h.transpose(1, 0, 2)):
            dV += np.dot(h_current.T, d_out_current) / batch_size
            dc += np.average(d_out_current, axis=0)
            dh.append(np.dot(d_out_current, V.T))

        dh = np.array(dh).transpose(1, 0, 2)

        return loss, dh, dV, dc

    def update(self, dU, dW, db, dV, dc, eps=1e-6):
        # update memory matrices
        self.memory_U += np.square(dU)
        self.memory_W += np.square(dW)
        self.memory_b += np.square(db)
        self.memory_V += np.square(dV)
        self.memory_c += np.square(dc)
        
        # perform the Adagrad update of parameters
        self.U -= self.learning_rate * dU / np.sqrt(self.memory_U + eps)
        self.W -= self.learning_rate * dW / np.sqrt(self.memory_W + eps)
        self.b -= self.learning_rate * db / np.sqrt(self.memory_b + eps)
        self.V -= self.learning_rate * dV / np.sqrt(self.memory_V + eps)
        self.c -= self.learning_rate * dc / np.sqrt(self.memory_c + eps)

    def step(self, h0, x_oh, y_oh):
        h, cache = self.rnn_forward(x_oh, h0)
        loss, dh, dV, dc = self.output_loss_and_grads(h, y_oh)
        dU, dW, db = self.rnn_backward(dh, cache)

        dU = np.clip(dU, -5, 5)
        dW = np.clip(dW, -5, 5)
        db = np.clip(db, -5, 5)
        dV = np.clip(dV, -5, 5)
        dc = np.clip(dc, -5, 5)

        self.update(dU, dW, db, dV, dc)
        return loss, h[:, -1, :]

# %%
def one_hot(batch, vocab_size):

    def _oh(x, vocab_size):
        x_oh = np.zeros((x.shape[0], vocab_size))
        x_oh[np.arange(x.shape[0]), x] = 1
        return x_oh

    if batch.ndim == 1:
        return _oh(batch, vocab_size)
    else:
        return np.array([_oh(s, vocab_size) for s in batch])

def sample(seed, n_sample, rnn):
    h0 = np.zeros((1, rnn.hidden_size))
    seed_onehot = one_hot(seed, rnn.vocab_size)

    h = h0
    for char in seed_onehot:
        h, _ = rnn.rnn_step_forward(char[np.newaxis, :], h)

    sample = np.zeros((n_sample, ), dtype=np.int32)
    sample[:len(seed)] = seed
    for i in range(len(seed), n_sample):
        # Calculate probabilistic output
        model_out = rnn.output(h[np.newaxis, :, :])
        # Choose next letter in sample with defined probabilty
        sample[i] = np.random.choice(np.arange(model_out.shape[-1]), p=model_out.ravel())
        # Forward current letter
        next_input = np.zeros((1, rnn.vocab_size))
        next_input[0, sample[i]] = 1
        h, _ = rnn.rnn_step_forward(next_input, h)

    return sample

def run_language_model(dataset, max_epochs, seed, hidden_size=100, sequence_length=30, learning_rate=1e-1, sample_every=100):
    vocab_size = len(dataset.sorted_chars)
    RNN = SimpleRNN(hidden_size, sequence_length, vocab_size, learning_rate)

    current_epoch = 0 
    batch = 0

    h0 = np.zeros((dataset.batch_size, hidden_size))

    average_loss = 0

    while current_epoch < max_epochs: 
        next_epoch, x, y = dataset.next_minibatch()
        
        if next_epoch:
            batch = 0
            current_epoch += 1
            h0 = np.zeros_like(h0)

        x_oh, y_oh = one_hot(x, vocab_size), one_hot(y, vocab_size)
        loss, h0 = RNN.step(h0, x_oh, y_oh)
        average_loss = 0.9 * average_loss + 0.1 * loss

        if batch % sample_every == 0: 
            print("epoch: {3}/{4}, batch: {0}/{1}, loss: {2}, avg loss: {5}"
                    .format(batch, dataset.num_batches, loss, current_epoch, max_epochs, average_loss))
            sample_encoded = sample(dataset.encode(seed), 200, RNN)
            print(dataset.decode_str(sample_encoded))

        batch += 1

if __name__ == "__main__":
    # Prepare dataset
    dataset = Dataset(32,30)
    dataset.preprocess("data/selected_conversations.txt")
    dataset.create_minibatches()
    # Start learning
    run_language_model(dataset, 50, sequence_length=dataset.sequence_length, seed="OVEUR:I see.  What do you think our alternatives are?\n\n")
# Out:
# epoch: 1/50, batch: 0/616, loss: 130.15872689381578, avg loss: 13.01587268938158
# OVEUR:I see.  What do you think our alternatives are?
#
# vXAeoleo3eddoeel
# o 7 iy.lN e6 eJBol
# hREZb2CZS!.gIIieeWuooe .oe eeOode   leo lloelemo
#  eiyooleu  e6el'  geoleeooei Ra  eMeYlooOwrOXl0MLFSb,wZ2ano
# epoch: 1/50, batch: 100/616, loss: 93.60978771123919, avg loss: 93.32533182588647
# OVEUR:I see.  What do you think our alternatives are?
#
# tal .    t fare d I ll  Yrpat mortSe o lQd se.p.eas ..  ,'nles. s .tT a
# t tot r.ullSe oucsoOar ye. ye yeliry.y y.uc y l ge. . E't'de  ulelearer,e
# epoch: 1/50, batch: 200/616, loss: 73.5808985186979, avg loss: 76.00346525225227
# OVEUR:I see.  What do you think our alternatives are?
#
# BCAB::
# E'xming buvecy ves rosly yseppanftre ctukesthisd  hAC!IK:
# Setne Fougu wt thamlt A8t meryr,sns pange?pI tp boul det p pednt hingif.'. whind
# epoch: 1/50, batch: 300/616, loss: 68.89015413852994, avg loss: 70.40562538693854
# OVEUR:I see.  What do you think our alternatives are?
#
#
# IDEO:
# Dep. Whit'd ta? d's you hat bt sd t's sanad ive. le ack th ther gh t. .wcoull toos. BEg chin'me trn theit d ir. fllgt cat ha fifg bonlv p
# epoch: 1/50, batch: 400/616, loss: 66.91409224109363, avg loss: 67.20661948038621
# OVEUR:I see.  What do you think our alternatives are?
#
# LE:
# I'd  it ouckeke boply borekele  atboronsmarean's ait time.
#
# HEN:HARTDE:SAnstdegruthe tu muvet burtns sto you ge one sot trere thalderr, she y
# epoch: 1/50, batch: 500/616, loss: 72.01427228316588, avg loss: 66.73416559156674
# OVEUR:I see.  What do you think our alternatives are?
#
# DR
# THADE:
# RTOROH:
# Whattone.s corre char talptcanleth as io geld us weren tothe of poos a, sst, fine on't an une. sashers furet wimien.
#
# MR thing
# epoch: 1/50, batch: 600/616, loss: 59.02261800904833, avg loss: 67.2262537527598
# OVEUR:I see.  What do you think our alternatives are?
#
# DEwey jowt lave wat'me  abe, us'r sas fot thay toe ua.
#
# IND:
# Sack'vy bo ut. I my memere?
#
# GON:
# Shat litg.
# hpimekid. Win?. ANN:
# Nominuth,  ra macw
# epoch: 2/50, batch: 0/616, loss: 70.23847734218597, avg loss: 65.31505050078118
# OVEUR:I see.  What do you think our alternatives are?
#
# D, Whawe?
#
# SOm wed you't whe, I goost the. Dest, Jestsed sose, taleiy the ellarttom litre comedpurnyithing thit. TEBON:
# ITNr What to rra lion, Iv
# epoch: 2/50, batch: 100/616, loss: 62.950057907482616, avg loss: 62.66676549964593
# OVEUR:I see.  What do you think our alternatives are?
#
# OREMIND.
#
# SMENIA:
# I my Wur, oud e ho ad.
#
# GENN:
# Hon fulredrad You. Done cabe aness thert bo get letey aiman's ou be ba monyt fiivi I I serellat.
#
# epoch: 2/50, batch: 200/616, loss: 64.63215161206575, avg loss: 64.36305563903021
# OVEUR:I see.  What do you think our alternatives are?
#
# MRMCHM
# TMARRKAMTN:
# Chat tact carod fre, tomo the gror roing king pa caveret wering the treck. I verm on?
#
# THEY:
# That gethis you mas't fldw foreri
# epoch: 2/50, batch: 300/616, loss: 58.93566497268596, avg loss: 62.1538819212548
# OVEUR:I see.  What do you think our alternatives are?
#
# HEN:
# Whit reld it got.
#
# BEN:
# But fur?
#
# AOLE:
# Se be to don't that ann give what dost, ut. She seas.
#
# BEY:
# Whand the bere se thas comt you it, lloo
# epoch: 2/50, batch: 400/616, loss: 60.75620556670801, avg loss: 61.46669989562779
# OVEUR:I see.  What do you think our alternatives are?
#
#
# RERE:
# Geevin's Ale plest this the buro:
# ust it bere?
#
# AREIE:
# Any oreof of atheris the as angat misave th.  cub tost're cing.  une. .SZo the the
# epoch: 2/50, batch: 500/616, loss: 67.24623486941721, avg loss: 60.67566776370247
# OVEUR:I see.  What do you think our alternatives are?
#
# ITATAN:
# Mal rim.
#
# ARDELIGORARTHINDRTTawt'd, Dsofren't toop is stamking SYle is I sest.
#
# JOKE:
# Snadl ther. What. Frrny the go suft p. ILANCOST2:
# I
# epoch: 2/50, batch: 600/616, loss: 53.60448289480338, avg loss: 62.46900349257584
# OVEUR:I see.  What do you think our alternatives are?
#
# LUOANIN:
# I feks..
#
# HAN:
# Yor here dun't atire ted sodeing what ans, ero tun an.
#
# ALUK:
# :s tho fad theretbomning tho  frice. Nowe. THon.
#
# CORA, tha
# epoch: 3/50, batch: 0/616, loss: 65.7587687319887, avg loss: 60.80534966347578
# OVEUR:I see.  What do you think our alternatives are?
#
# DAVER:
# Whttked wase  Saret lust, her thaf therit it.
#
# SMAREMAND:
# Cher gonAre?
#
# LOURM:
# Wheny, doly aormened you. Fe's the.
#
# CELRERX Sulfos?
#
# EELEC
# epoch: 3/50, batch: 100/616, loss: 59.137239555691174, avg loss: 58.92299716963455
# OVEUR:I see.  What do you think our alternatives are?
#
# Gll bat aider. As. Hisg syout. The l. I dored NDE8FFR:
# Hack worerably.
#
# DONECKAN:
# Ick you Goush.
# AONcare do wat's gork.
#
# DORDOND:
# I? I kich the
# epoch: 3/50, batch: 200/616, loss: 62.199907282947976, avg loss: 61.3893240706327
# OVEUR:I see.  What do you think our alternatives are?
#
# REDy you wan serter Gollicher anlet so you thoula sing'le thelkund litt fron't ny.
#
# DOMMind hire, juid.
#
# DR... noe ttorly. thay'r just... nod tor
# epoch: 3/50, batch: 300/616, loss: 55.47149847571794, avg loss: 59.451573143210965
# OVEUR:I see.  What do you think our alternatives are?
#
# VER:
# Wem shat gon.  cry flake be is coml, gut? Pranmr? Shing fene...
#
# HIN:
# In's torc. Momy, has?
#
# MEN:
# Hey you de ged a gug that a bink it men yo
# epoch: 3/50, batch: 400/616, loss: 58.814551157821114, avg loss: 59.270124946126124
# OVEUR:I see.  What do you think our alternatives are?
#
# THUS Silly.. Enat the estitge, tee?
#
# VAREY:
# She ther that my cour doman for med thit's tre tot you.
#
# HRERE:
# Erect hon toubave. . Thed yf whe lut
# epoch: 3/50, batch: 500/616, loss: 65.24434093370249, avg loss: 58.49410279452793
# OVEUR:I see.  What do you think our alternatives are?
#
# MR. PI weyere live is a sice talvers in a I docf for  rach do wis alon. Exaxidfe dredtir Dope, ans whonm.
#
# ILVIRE:
# Rm. now juid saget?
#
# HR. The t
# epoch: 3/50, batch: 600/616, loss: 51.27352284474587, avg loss: 60.47269363596333
# OVEUR:I see.  What do you think our alternatives are?
#
# CODLO:
# Uuiss getre...
#
# UOMANT:
# I wiot tHe rised. NTIET? I wan'...
#
# DELAPO:
# All for meenes nevat wion howareane dion thit you wenckire you Oeed al
# epoch: 4/50, batch: 0/616, loss: 63.74425261473055, avg loss: 59.012091752982606
# OVEUR:I see.  What do you think our alternatives are?
#
# at macercoget he hea, akend pasw cou dident. I comestiintisheve nery the herd's and arou'r as justrestons epud?
#
# CERLER:
# I wext tithe'm yould?
#
# S
# epoch: 4/50, batch: 100/616, loss: 57.33082814530659, avg loss: 57.0965748925985
# OVEUR:I see.  What do you think our alternatives are?
#
# GRENDIE:
# No shey you gply?
#
# DINNE:
# G be nver has, yon pernow some, I ithillyselly. You'dpose's but co.
#
# MR. We'm appo live hest.....
#
# CORE:
# I kna
# epoch: 4/50, batch: 200/616, loss: 60.54748492002402, avg loss: 59.71809345829038
# OVEUR:I see.  What do you think our alternatives are?
#
# BERYN:
# Nor.
#
# DAR. To goiss ging thare? I'm nolr, I hightt comeR...
#
# DETRGIRBuckidid chance lint wanka, it plaut, awnavan, now wire to be re as ce
# epoch: 4/50, batch: 300/616, loss: 53.93010466283647, avg loss: 57.88929908604499
# OVEUR:I see.  What do you think our alternatives are?
#
# PWHE:
# He shere slis it aflunn, jo ea. I gingpiof og J, anta id.
#
# CI woulrou yrugh he buck it. Aifiven paring murst uliemids, thaty love four a? S
# epoch: 4/50, batch: 400/616, loss: 57.27940813429842, avg loss: 57.87748226335687
# OVEUR:I see.  What do you think our alternatives are?
#
# DASEL:
# St's Shit!  The what. hare this it muLen?
#
# Sant.  hat hastnt.  Loenederscolt's thers eve of I cowerighlater even know ne's fint, is the wo
# epoch: 4/50, batch: 500/616, loss: 64.0761621798712, avg loss: 57.17963386340794
# OVEUR:I see.  What do you think our alternatives are?
#
# MR. SEMARAD:
# Your sheret a dun on gos aspin sh you cond fad.
#
# FFRMLOCK:
# What's frl. You bene where here the car dilmon weneves not you mersterste
# epoch: 4/50, batch: 600/616, loss: 49.644673385246996, avg loss: 59.17695546992516
# OVEUR:I see.  What do you think our alternatives are?
#
# IUSART:
# The this?
#
# GURARAN:
# Ns I mahey.  What a cllanter!  o ack ut the gona aget that think are anoveae as for this....  re mant...
#
# LaPR MALLE:
# epoch: 5/50, batch: 0/616, loss: 62.45378042185834, avg loss: 57.81390545001603
# OVEUR:I see.  What do you think our alternatives are?
#
# STE:
# I's would whis.
#
#  BY think you do fig surdce daht..
#
# SANR, funt atsoundo?
#
# LEER:
# ISA:
# He's a ready I've greding year oures.
#
# FFRLIA:
# Hod ome
# epoch: 5/50, batch: 100/616, loss: 56.27869541979052, avg loss: 55.844751487788166
# OVEUR:I see.  What do you think our alternatives are?
#
# DR. Ylucseshen ol Cor jar. I gook in outhould Hele dras on that dad stol.
#
# SGEN:
# Whote y you kior serst of I Fund spnan. . frure thenesestader to
# epoch: 5/50, batch: 200/616, loss: 59.09686427587927, avg loss: 58.60962573580382
# OVEUR:I see.  What do you think our alternatives are?
#
# ENGHOR:
# Are I leell? Chat you a preabandenimy shis reablloge batt.
#
# ERmo his to there's busterliellin' watt or a moal, inetsuning a chime one's s
# epoch: 5/50, batch: 300/616, loss: 53.00205082908311, avg loss: 56.809637420884805
# OVEUR:I see.  What do you think our alternatives are?
#
# THAR:
# Yiver andy.
# . tomonded enersa tean. You to con or be trist think, mik you you an stony?
#
# BNE I ca bar0.
#
# JICH:
# Now!.. io weyt wout go can y
# epoch: 5/50, batch: 400/616, loss: 56.19157026831058, avg loss: 56.85369055221952
# OVEUR:I see.  What do you think our alternatives are?
#
# AR:
# You'll do, are?
#
# SEBARE:
# That Wayingtert. You there cours ut.
#
# REY:
# May.  Sowe the taktrry you bad to there onabut fem it dily Son the and th
# epoch: 5/50, batch: 500/616, loss: 63.32763093306883, avg loss: 56.26813894866167
# OVEUR:I see.  What do you think our alternatives are?
#
# CHINMA:
# Slins thit bore thenn op. Bur it.
#
# JOFZORANDA:
# There fong therwhor? sear wap ne five?
#
# MR. PIN:
# Met out ontat's mint. Somert youstris.
#
# H
# epoch: 5/50, batch: 600/616, loss: 48.70773181741154, avg loss: 58.211192339278064
# OVEUR:I see.  What do you think our alternatives are?
#
# LANGOY:
# Nit. Aacely that's this book. LANDO:
# Yes.
#
# DECIN:
# Aramt But d fod bat?
#
# DES...
#
# MR..
#
# LEDAY:
# Douadly liver it I f ged?
#
# NONSAD:
# Fe if was
# epoch: 6/50, batch: 0/616, loss: 61.38670340943846, avg loss: 56.845313353528965
# OVEUR:I see.  What do you think our alternatives are?
#
# LAURA:
# Andors one you wim and cha gobod that eunt wang, Shouruokent of you'd  ofs toncesanywirene ghere, jover kmystes hate rrigh.
#
# SMAR:
# Hhat fo
# epoch: 6/50, batch: 100/616, loss: 55.46633826836645, avg loss: 54.977102194935945
# OVEUR:I see.  What do you think our alternatives are?
#
# MR. Welly and.
#
# GRe tove Gound. I've are we golllightee for an is thank diversill be this moorlve st.
#
# INAE:
# I've pornd you.
#
# DONDONN:
# But you're
# epoch: 6/50, batch: 200/616, loss: 58.01147547181792, avg loss: 57.742268185025715
# OVEUR:I see.  What do you think our alternatives are?
#
# BECK:
# DOnw and wit?  nhe have he save wo gelt thind swiall elshe juxt My that haver I just limer.
#
# REBVER:
# That?
#
# RARAAN:
# Yout  juso feousl's I'm
# epoch: 6/50, batch: 300/616, loss: 52.37020307927284, avg loss: 56.014348107409404
# OVEUR:I see.  What do you think our alternatives are?
#
# DY:
# Oks a list you?
#
# BIPEWHY:
# How are.
#
# HAN:
# Yed. He saly, I uus besin.!
#
# Loulded ale hat some cale proghtutby have you I a arne beow light... ev
# epoch: 6/50, batch: 400/616, loss: 55.344088474147696, avg loss: 56.01701321475065
# OVEUR:I see.  What do you think our alternatives are?
#
# OHE:
# Yes. The goby?
#
# SANDY:
# I ditime're thin. Hown frond.  nthou wantsed the lanes wos.
#
# HANZO:
# Tees.
#
# YROSE:
# GONELRESTH:
# You shered.
#
# TERER:
# The
# epoch: 6/50, batch: 500/616, loss: 62.873998824679774, avg loss: 55.578605002750244
# OVEUR:I see.  What do you think our alternatives are?
#
# TEPRA:
# Whis saget for dians a deesp everod wnast, wim. You dor.  DONK Have.
#
# SARA:
# Muming  hock tien me somris sider but a wheacking arvoring...
#
# epoch: 6/50, batch: 600/616, loss: 47.91623100825576, avg loss: 57.462857055073776
# OVEUR:I see.  What do you think our alternatives are?
#
# LOUNRESSRBORMAN:
# Yes. A an don, you for now me, dee ticking so you. DONL I Lisisn id no frick righat?
#
# DALLANN:
# I MAUN:
# Meaco?
#
# SYANE:
# L Are, in'
# epoch: 7/50, batch: 0/616, loss: 60.43841622201385, avg loss: 56.08752873633362
# OVEUR:I see.  What do you think our alternatives are?
#
# LLIUR:
# Ald a bee ...
#
# LEORE:
# Hean hidg to the fom do to here heres a Beased you now.
#
# LARATT8Y:
# Surd mowelloust is bot rott ayt IThe you bamynon.
# epoch: 7/50, batch: 100/616, loss: 54.75748940715147, avg loss: 54.2910251392567
# OVEUR:I see.  What do you think our alternatives are?
#
# DR. PINH......
#
# DEN:
# Yeargered ou he'll got pronge nught., Fver awoneaky hear bit?
#
# DERY:
# The.
#
# CErw you'llshac, I don't reifation thuico of ever
# epoch: 7/50, batch: 200/616, loss: 57.34549014188518, avg loss: 57.088714738808285
# OVEUR:I see.  What do you think our alternatives are?
#
# JECER:
# I mer cho I allomel are yournet, whink cowinc're of taldee ceden't it that and anleithing, goine is here you?
#
# CRMDDY:
# Yeareen the froboke
# epoch: 7/50, batch: 300/616, loss: 51.89576243188942, avg loss: 55.33878169726211
# OVEUR:I see.  What do you think our alternatives are?
#
# PEFFARY:
# Tall the diseround inde melontelly tear.! Y:
# It ankwry do takete, about mirmabor, And ttaf is on fell reff you get a can fund. But ess w
# epoch: 7/50, batch: 400/616, loss: 54.699795165363916, avg loss: 55.37644018585878
# OVEUR:I see.  What do you think our alternatives are?
#
# SORA:
# What pussup the be verut sextick you tike?
#
# CERVERE:
# Ehcow you shind aplet.  reee's ..
#
# LARE:
# Syswen.
#
# CHERE:
# Yeredor.  Thatvissen ..rnest
# epoch: 7/50, batch: 500/616, loss: 62.39225655390384, avg loss: 55.04730673424187
# OVEUR:I see.  What do you think our alternatives are?
#
# MR. WHATE:
# You hame wayever gat Dead is Jeackseat cimberuth tell asy wis raistelfute. Nowan off! EBITOM:
# Yeaw over of know off ferwaly tore a if
# epoch: 7/50, batch: 600/616, loss: 47.3108574651523, avg loss: 56.83862265255425
# OVEUR:I see.  What do you think our alternatives are?
#
# JE:
# Yes.
#
# LALLIER:
# I Sa wastiog the are wos? Chut Dodan tole, but untat wattought Bit..
#
# KODPR:
# Lot smithen a fees.
#
# DONNA:
# Or. Shrs fer das and
# epoch: 8/50, batch: 0/616, loss: 59.599484269728876, avg loss: 55.49670497608271
# OVEUR:I see.  What do you think our alternatives are?
#
# HANR:
# Yournem.
#
# LEFARG:
# I crrto trand to trard Hatcee nysest. I'mey listaill to call of Fourn?
#
# on to frrstat wake wink that's I were ond.
#
# JEWIE
# epoch: 8/50, batch: 100/616, loss: 54.067734770908, avg loss: 53.68329722479138
# OVEUR:I see.  What do you think our alternatives are?
#
# MONNE:
# Os.
#
# DENDY:
# I going sis wy.
#
# DONGEY:
# Twhath this do so thoueckind be younaabit.
#
# DR..
#
# FERDY:
# Thin foke with me me's not mush tive she.
#
# A
# epoch: 8/50, batch: 200/616, loss: 56.851826049841236, avg loss: 56.54023763504925
# OVEUR:I see.  What do you think our alternatives are?
#
# HER:
# ABme nothoncan. Why a teuld. Do do could cas ake wamwn've outremires?
#
# LRMAN:
# Yet ste fulding one, Casvarmed.
#
# GONATERY:
# Nody be he whitl yo
# epoch: 8/50, batch: 300/616, loss: 51.54872871754429, avg loss: 54.76167850929435
# OVEUR:I see.  What do you think our alternatives are?
#
# LRIt per ngts prommonts. Sow t'll sixped.
#
# GOHEY:
# He for the mest killing to these.
#
# BELLIA:
# You. Bled un.  Shithling wan Everyse, you of mappinc
# epoch: 8/50, batch: 400/616, loss: 54.15814884971418, avg loss: 54.83913521986898
# OVEUR:I see.  What do you think our alternatives are?
#
# HE:
# Raty.
#
# STER:
# Itthe seal.
#
# GEs hoong be lotraner beotat.
#
# FREAR:
# Grtitie to do saven't lovery youthing rina bo the to rmind.
#
# REELEESS:
# Gure b
# epoch: 8/50, batch: 500/616, loss: 61.86571455777715, avg loss: 54.576706337021456
# OVEUR:I see.  What do you think our alternatives are?
#
# JE Mening angurnsatisustaisely hearl you.
#
# RAVERICK:
# I shehere carss. I setad fuct. WER:
# She comethinc cupme.
#
# MR. PITO:
# You foruicge, so you not
# epoch: 8/50, batch: 600/616, loss: 46.808345981559384, avg loss: 56.343062776122366
# OVEUR:I see.  What do you think our alternatives are?
#
# AANN:
# I'm yournt.
#
# LOUR!
#
# DA607 nom for g roodly lrig thing don't, CULOS OR? Tid beet a par it just.
#
# VIARDELLU:
# I tell for a plyne.
#
# LOURA:
# Fo i
# epoch: 9/50, batch: 0/616, loss: 58.97062592186623, avg loss: 54.9776222853646
# OVEUR:I see.  What do you think our alternatives are?
#
# JORBAN:
# What?
#
# DES:
# Qusay.
#
# KARD:
# I've it. SOONZO:
# Or?. I'm, why kinka did and a busted styou ugeded do you're here ind reedmand weaged dnoce the
# epoch: 9/50, batch: 100/616, loss: 53.43312740370813, avg loss: 53.188379013218196
# OVEUR:I see.  What do you think our alternatives are?
#
# DYLEIN:
# No. Chey there for arour bo that and owiridn?
#
# DONNIE:
# Goonsu in thoukefe pucchingion. Gor ans.
# SDOFFRY:
# Ok. Dorrely and men thing to tho
# epoch: 9/50, batch: 200/616, loss: 56.38612269642162, avg loss: 56.056875543161624
# OVEUR:I see.  What do you think our alternatives are?
#
# LOTAN:
# NK bully. .nkily.
#
# RARTHER:
# What. he'r 11FFRETTREMplos.
# Do the this?
#
# PER:
# I wanter trave thit at who thi hink you's minged know, dy dente
# epoch: 9/50, batch: 300/616, loss: 51.246617754973045, avg loss: 54.30191594970701
# OVEUR:I see.  What do you think our alternatives are?
#
# RAXD...  I couls lime expe srop to  muss sto te I bo got Onke be you, 2 mitch a shith ig have the bect.
#
# DY:
# Dien you westecb stuse to bit're it
# epoch: 9/50, batch: 400/616, loss: 53.70157225185272, avg loss: 54.40487431527997
# OVEUR:I see.  What do you think our alternatives are?
#
# THER:
# Read but that wedisan...not Oike.  The frike is ttood.
#
# RA:
# The.
#
# MANE:
# Pesertids.
#
# HAR:
# We. Let estidn't be year it fur throw. It's it's m
# epoch: 9/50, batch: 500/616, loss: 61.41295275665952, avg loss: 54.177416194126714
# OVEUR:I see.  What do you think our alternatives are?
#
# DONNIE:
# No. What coulugus is? I does mofehers. I dueff by nlk are was proby might a done. me houl thit bit's yourstar, net, gigct?
#
# MADDY:
# I can
# epoch: 9/50, batch: 600/616, loss: 46.36908494968203, avg loss: 55.929683873012486
# OVEUR:I see.  What do you think our alternatives are?
#
# CINGEY:
# The ded My.  mi s nol the drie bedy in get innt?  Do.
#
# JOEN:
# Don't an mman soul whell morkhen they dive of the boo.
#
# CANUONE:
# No.
#
# MANNA:
# epoch: 10/50, batch: 0/616, loss: 58.475010107750016, avg loss: 54.55095860641066
# OVEUR:I see.  What do you think our alternatives are?
#
# LAURA:
# I'l Licile, What suspater thay hort? hure. Preting you're. Theys wasto meast of thinks what Dpe geab, the tous bork. nexproner in vey. Tes
# epoch: 10/50, batch: 100/616, loss: 52.977117478006775, avg loss: 52.79288154836304
# OVEUR:I see.  What do you think our alternatives are?
#
# DONNIE:
# Houm.
#
# COLNIE:
# Get the gein there ON:
# Okers?
#
# DOVAWNITE:
# GONGHE:
# What cant be. Wilr I go in knot snitus this, wad yeed to somethat hers..
# epoch: 10/50, batch: 200/616, loss: 56.02992107962011, avg loss: 55.655699076681366
# OVEUR:I see.  What do you think our alternatives are?
#
# DONN:
# I've is like chund the allen! IsK.
#
# TRaze jubt got to sur the ot with there is show mo, yet.
#
# CONRO:
# I here thinn they looka exinj, tck you
# epoch: 10/50, batch: 300/616, loss: 50.95827281052425, avg loss: 53.91286741209619
# OVEUR:I see.  What do you think our alternatives are?
#
# BEN:
# I manthurd mappesis lavatedodinit.
#
# MANMIN:
# Hearloucher of you docandfor. Well allmwand.....
#
# SI wouldounti...
#
# CINDY:
# How about maken you m
# epoch: 10/50, batch: 400/616, loss: 53.33867068575037, avg loss: 54.04737382701304
# OVEUR:I see.  What do you think our alternatives are?
#
# YELKE:
# AsKSe ably.
#
# EARAH:
# I?
#
# SERESSE Fully to.  houbt conve adlue sigevert.
# RAREA:
# Thesshorn you'r just gethos?  Wely ondy.  Yes! AS. sworousti
# epoch: 10/50, batch: 500/616, loss: 61.03816094420594, avg loss: 53.845030965044245
# OVEUR:I see.  What do you think our alternatives are?
#
# BRARA:
# Whill all ther so knowle tood.
#
# MR. THURDEFF!
#
# KARTONKE:
# I mpen.
#
# MR, Beacr talkays. BIEN:
# No.
#
# HAWE:
# Whin is MEven't, I tiedd I win it be
# epoch: 10/50, batch: 600/616, loss: 45.97844560520482, avg loss: 55.56954067008259
# OVEUR:I see.  What do you think our alternatives are?
#
# DOS INNO:
# You. This docononed. But B. I woulda is eveliniend they raded one wered dy lrayjoage a gols ondy he's hela.
#
# STAN!
#
# DACRETIGOR:
# NONEBAR
# epoch: 11/50, batch: 0/616, loss: 58.07324103380118, avg loss: 54.17837187803479
# OVEUR:I see.  What do you think our alternatives are?
#
# LEARTE:
# A holr goodore are carem is a jusk ome thut ywick right live spoter the sorrion ming abl us fint is?
#
# JEXROST:
# I?
#
# PEN:
# Peeversiar. You a
# epoch: 11/50, batch: 100/616, loss: 52.62877539851877, avg loss: 52.46513682930157
# OVEUR:I see.  What do you think our alternatives are?
#
# DWREISHITHITNIE:
# Tiss.
#
# SANDY:
# Wim trall your we wan't I thell to sfing it it dill to CHURYROE:
# That's mean. I goesser leo?
#
# DD. hucls!  me Ma?..
# epoch: 11/50, batch: 200/616, loss: 55.67455157329441, avg loss: 55.34294435218764
# OVEUR:I see.  What do you think our alternatives are?
#
# EYRY:
# Bidn't the to dick of onet of dall. Why I came, bo, your fum.
#
# DETRIST:
# De.
#
# CENRY:
# You..
#
# DOREPEY:
# I coullay to I fanch the the have a mi.
# epoch: 11/50, batch: 300/616, loss: 50.67071261118886, avg loss: 53.57583518874388
# OVEUR:I see.  What do you think our alternatives are?
#
# SAUFAY:
# You diss Abory.. I waull that's that this onn!
#
# BER:
# Mlling there f it.
#
# BINN:
# Fous wire God.. Where's like dand hay, lokON:
# Bitning on a
# epoch: 11/50, batch: 400/616, loss: 53.037846231565034, avg loss: 53.73102512945254
# OVEUR:I see.  What do you think our alternatives are?
#
# SOHALESE:
# O...
#
# SARAHE KOR, fot you sner... must is got that thinde.
#
# THARY:
# That wester couldo tad.
#
# SEOP:
#
# OOSEON:
# Rige fect ma.!
#
# WERRIE:
# Loon
# epoch: 11/50, batch: 500/616, loss: 60.77324164477888, avg loss: 53.557673923532356
# OVEUR:I see.  What do you think our alternatives are?
#
# PINGLE:
# Mridy, one finy hias doy the shestamory want.  walks woffarg be ongrethiror canog that the fig.
#
# RDDAN:
# When that die gob. Gren you dears
# epoch: 11/50, batch: 600/616, loss: 45.66112516110026, avg loss: 55.254178940405524
# OVEUR:I see.  What do you think our alternatives are?
#
# DHE:
# Dlan ht not of befoughing think, Ist bif ag6. What fry with Wongam.
#
# JY!
#
# MALLAN:
# Nmeabed you're me you talp this hought, iver forauged...
#
#
# epoch: 12/50, batch: 0/616, loss: 57.68922252465519, avg loss: 53.84065228648413
# OVEUR:I see.  What do you think our alternatives are?
#
# BRELE:
# Int of you are you... I'm owe, I'd the seuch no teed stad worern bectump astat?
#
# LOEL:
# Lowe woflod worr, ylutiss.
#
# LAURE:
# Whink a fime jus
# epoch: 12/50, batch: 100/616, loss: 52.31846314270949, avg loss: 52.18178105999151
# OVEUR:I see.  What do you think our alternatives are?
#
# DONPE:
# HENNZOF:
# Whond trard ust you know you sod, heridg.n liver timryal....
#
# FREDRETHR:
# Soffale. She sen hactheaze weyterfer saybo Fuctiint.
#
# DO
# epoch: 12/50, batch: 200/616, loss: 55.32766872022295, avg loss: 55.096219186492405
# OVEUR:I see.  What do you think our alternatives are?
#
# TRATH:
# What's frinds.  LAIPER:
# It's yen Mo. That'll for.
#
# MANRCKER:
# Whes for the sh yours mice whed me is where? Can touterell you'lliny init?.?
#
# epoch: 12/50, batch: 300/616, loss: 50.406571476299, avg loss: 53.27642907272213
# OVEUR:I see.  What do you think our alternatives are?
#
# DAMEWe back is the hink a. .., she, I don't streap latte un e goon.
#
# EE:
# You'll intern nobar fugile.  Nowty...I'm so yeare to sed arre some ave f
# epoch: 12/50, batch: 400/616, loss: 52.78448655320946, avg loss: 53.4553540389994
# OVEUR:I see.  What do you think our alternatives are?
#
# ERASE:
# I'd I kars....  in tor bed.  on a llok yot in thembelot the buwn...
#
# SAEAN:
# You're, I'm Gike.
#
# LUKAR:
# Stag7 thaps one two. I Sure a bit.
#
#
# epoch: 12/50, batch: 500/616, loss: 60.560079010956876, avg loss: 53.293619625186224
# OVEUR:I see.  What do you think our alternatives are?
#
# MR.
#
# BRHERMANDE:
# It get in thit.
#
# ELKI whol.  cally.
#
# MR. BED:
# No fuck me. So siftif we facaing, but in a buck, wly you what that abERIMAY:
# Al?
# epoch: 12/50, batch: 600/616, loss: 45.41752144868705, avg loss: 54.97475702123289
# OVEUR:I see.  What do you think our alternatives are?
#
# GONNY:
# Willy. We't a clm ... of tell wontto nee.
#
# DUKAP... Your coulu. Wu wath. Dr  When she lind not to tevele. Athe goin, tra.
#
# LAURA:
# Afont, i
# epoch: 13/50, batch: 0/616, loss: 57.33426633159785, avg loss: 53.54619941152119
# OVEUR:I see.  What do you think our alternatives are?
#
# MALLE MON:
# Soght and they Ma think, aps it tholl, lott therehere would buting know your would rhoye? Luad celt, you the sure.
#
# SASAR:
# Havernlejin
# epoch: 13/50, batch: 100/616, loss: 52.02636783104502, avg loss: 51.923336572700684
# OVEUR:I see.  What do you think our alternatives are?
#
# GRE CONDE.
#
# RENRE:
# Simes whenow an mutil...
#
# DRRI'll a Wh'l they they oll us homg... just waithing Mw. a don't will drir ard fucks sulded ale ple
# epoch: 13/50, batch: 200/616, loss: 54.97411427821733, avg loss: 54.87171386226587
# OVEUR:I see.  What do you think our alternatives are?
#
# CHRRBEN:
# Treeterese.
#
# BEN:
# You're a there's hat a leke are t herpy stilpe paft you fuake my it, I sught they cara cilpnd the sore it ta mixorsera
# epoch: 13/50, batch: 300/616, loss: 50.17528970186876, avg loss: 52.99691556002084
# OVEUR:I see.  What do you think our alternatives are?
#
# You.
#
# HONDY:
# Fod you callurst gok, CHIWICK:
# OkE You very gone like the diay. I toe preabor boing, bely inot back. Yoi't dayfes telk tund in I'm n
# epoch: 13/50, batch: 400/616, loss: 52.577368553700126, avg loss: 53.21568232219276
# OVEUR:I see.  What do you think our alternatives are?
#
# HAN:
# EBESTER:
# Real.  Ar misumar lalkianstre me!  He'm stieng?
#
# SANDE:
# A me.
#
# SAN tyouble to tell spof rime us. HRE:
# Yer, jusk if.  duidn penile's
# epoch: 13/50, batch: 500/616, loss: 60.24571452125922, avg loss: 53.05110867077914
# OVEUR:I see.  What do you think our alternatives are?
#
# JOM:
# Lit, pets?
#
#
# JAR M1?
#
# RISELEAT:
# They just tond face. Pore a the just that proping eind dear, just I donatat? remmat.
#
# FARLE Fuck a pary thea
# epoch: 13/50, batch: 600/616, loss: 45.2172633174317, avg loss: 54.7244051877307
# OVEUR:I see.  What do you think our alternatives are?
#
# LAURA:
# No you to sey, Not sowe that motorritta? You'm do is a magwrenychang when the e you hoserno most going, inday?  It'  in botioner?
#
# LEUSA:
#
# epoch: 14/50, batch: 0/616, loss: 56.97182161064102, avg loss: 53.28639635513528
# OVEUR:I see.  What do you think our alternatives are?
#
# JOAN Eveann thing the do be incter blcee? Toreling itperaknire's Skith.
#
# JECKARA:
# Wesithal are, what we kang comaneatien.? cering up then kicvaty
# epoch: 14/50, batch: 100/616, loss: 51.758460330669664, avg loss: 51.68417012396461
# OVEUR:I see.  What do you think our alternatives are?
#
# MRMMAN:
# No! You justile..reytha't lata chisn't nt boneray... Geal, there's Mand.
#
# DONNIE:
# That being sor at coog.
#
# SRONNIE:
# I doped you the reaun
# epoch: 14/50, batch: 200/616, loss: 54.661970074509426, avg loss: 54.66946681374045
# OVEUR:I see.  What do you think our alternatives are?
#
# ERMAN:
# Nett anE my ercis nl promes, thitels marffouind.
#
# PERTHRER:
# Wellis a buck you have hammurding for re someth, but what the a hill where you
# epoch: 14/50, batch: 300/616, loss: 49.99578480504346, avg loss: 52.74422582909425
# OVEUR:I see.  What do you think our alternatives are?
#
# BANDY:
# Ost sourse partay, the bothang.
#
# Ma prive to yeestanna about Giver who hape, I amofoman, Yingondaight.
#
# HAN:
# We. Cell 200000 a we't wire i
# epoch: 14/50, batch: 400/616, loss: 52.37971193115598, avg loss: 53.004004298476964
# OVEUR:I see.  What do you think our alternatives are?
#
# SARAH:
# St's id is andine about try hempst... EYSER:
# Lath.. Hudrras.
#
# KORPER:
# No, can.
#
# CANRE:
# Well in thiter our up what Sill buht tidry hare my
# epoch: 14/50, batch: 500/616, loss: 60.00279649206056, avg loss: 52.84019668255923
# OVEUR:I see.  What do you think our alternatives are?
#
# FRESPION:
# You saxonvefing a riftillce in feep you wear, afomer blize are.
#
# DREDDY:
# When that I'm fisked bake Want finy'f this about it, opeded, y
# epoch: 14/50, batch: 600/616, loss: 45.03762327537795, avg loss: 54.491876652619574
# OVEUR:I see.  What do you think our alternatives are?
#
# LOELE soidn't kill a kintils...
#
# DANDEY:
# You gme me don't raf, you tidn't you this, I've gunthe in about kind you up I that had?
#
# JOUSA:
# You orau
# epoch: 15/50, batch: 0/616, loss: 56.61299441229754, avg loss: 53.05618600670367
# OVEUR:I see.  What do you think our alternatives are?
#
# PESte nouldy of tid.
#
# LAURA:
# Do a Don and husting or dien thorgh are gat tildannon. It'd, was hobe now so?
#
# COMTLERS:
# A bethereris on a stulliser
# epoch: 15/50, batch: 100/616, loss: 51.52681007024542, avg loss: 51.4600228968961
# OVEUR:I see.  What do you think our alternatives are?
#
#
# CONNIESTHEMA:
# I do dring till rabue 20 this beeal nealin tholewhrow mawiru. Thin?
#
# GOBMOND:
# Ohilis.
#
# DONNEY:
# Do. You'll to Aive ort.  Come wit c
# epoch: 15/50, batch: 200/616, loss: 54.392940092264695, avg loss: 54.48016496272894
# OVEUR:I see.  What do you think our alternatives are?
#
# BETTY:
# Thear, whe Bucry what goodry that! That's honce firking and over?
#
# LEIDER:
# We's hall for to memandy you mes I'm ILEDY:
# That.
#
# MK..
#
# ROTHOR
# epoch: 15/50, batch: 300/616, loss: 49.849975835122, avg loss: 52.5207119863188
# OVEUR:I see.  What do you think our alternatives are?
#
# LEICE:
# I plan famy.
#
# PROFE. Fill take and a joldy?
#
# PION:
# You viss latt barry wame God dnet have frugg holdar.
#
# DAT RAIDOY:
# ITOMGEY:
# Hees the lis
# epoch: 15/50, batch: 400/616, loss: 52.19266454403935, avg loss: 52.80727121387495
# OVEUR:I see.  What do you think our alternatives are?
#
# REE:
# Yes... yot.  Bets the porteibed that's there.
#
# LEIA:
# Rum. Con.  fuse?
#
# ARER:
# Not never kiddavistoodned.
#
# LECAN:
# You you the cold hes shiever
# epoch: 15/50, batch: 500/616, loss: 59.75657073486158, avg loss: 52.63899373971955
# OVEUR:I see.  What do you think our alternatives are?
#
# MR. THYPHN:
# Yes.  The a was there owe up the hahe doing dieldn't chempap werat in neveet out's shomer. He furow and then thebe or ove so fake it
# epoch: 15/50, batch: 600/616, loss: 44.84450267467359, avg loss: 54.26833804812105
# OVEUR:I see.  What do you think our alternatives are?
#
# MONDONGERLOMENT:
# It's hinneep.. Lef...... dub, Lue in mon fine what mike a nos wang.
#
# SONDIERDAN:
# What tought all ming like in that tir.  It?
#
# JI
# epoch: 16/50, batch: 0/616, loss: 56.29431710681923, avg loss: 52.84681049987004
# OVEUR:I see.  What do you think our alternatives are?
#
# EVEREY:
# It's. I meel?
#
# SARDLAEl HEy me and the do your it of that he's extarivifhe the just was you was fick of Losn't thet effing tould, incels
# epoch: 16/50, batch: 100/616, loss: 51.32765126197448, avg loss: 51.24724216587946
# OVEUR:I see.  What do you think our alternatives are?
#
# VARON:
# Ghat batlech rave  get Hame ald it losher has you worthing to droin Dean hey ...the mowhat I dean dy. Nore theys ccare?  the prome are, lo
# epoch: 16/50, batch: 200/616, loss: 54.1513113764519, avg loss: 54.296184044636384
# OVEUR:I see.  What do you think our alternatives are?
#
# JOANK:
# Used. He's my my cletern. That's be sushe dost mets a waitherr... Now at.
#
# HENRY:
# You're they?
#
# DOMAN:
# You kind've was the berouse?
#
# EVERO
# epoch: 16/50, batch: 300/616, loss: 49.70614530941051, avg loss: 52.31715807730255
# OVEUR:I see.  What do you think our alternatives are?
#
# LUKE:
# Coriug you forabo, baing. It.  Pyite?
#
# BYAONSIHR:
# Dan to you know, Or of it no. Ald you arainf to didn't in ont.
#
# HIN:
# Here IK!
#
# STITHY:
# Fu
# epoch: 16/50, batch: 400/616, loss: 52.01181254462185, avg loss: 52.622135144632615
# OVEUR:I see.  What do you think our alternatives are?
#
# REAP:
# Taght don't net, Andonin.  You thef of the me.
#
# REEPER:
# They Iidieve?
#
# VIAES:
# Shide them yell, out the morie.  you get to themunt.  but yes
# epoch: 16/50, batch: 500/616, loss: 59.51264970425538, avg loss: 52.45675345401974
# OVEUR:I see.  What do you think our alternatives are?
#
# MR. THre! Thendir. I'm this the somethem. I Madde. Whe weren won't a coviloces doese.
#
# MR. POOTE:
# But erattions seathing me. Why, haves way betiv
# epoch: 16/50, batch: 600/616, loss: 44.640715771054026, avg loss: 54.05647895272564
# OVEUR:I see.  What do you think our alternatives are?
#
# DONNGON:
# Lutret. Bul it thoce to beand for the are to are some way oner tike has is, ha
# Stheill.  I po you kny quif. Blan is for an her min'.  ID
# epoch: 17/50, batch: 0/616, loss: 56.01705253883473, avg loss: 52.65346663606709
# OVEUR:I see.  What do you think our alternatives are?
#
# LELAND:
# Mastenad.
#
# SALAOX.
#
# JEFFRE:
# What's got?
#
# BELL:
# Vims and galking dosy you that hey's wear the best you know that on hugure stront.
#
# CORTTE
# epoch: 17/50, batch: 100/616, loss: 51.149446689708334, avg loss: 51.051792393890814
# OVEUR:I see.  What do you think our alternatives are?
#
# MR. ICEE:
# Yes. I the uper.
#
# BENN:
# I ce he firt tcime that. I hond?
#
# GEANISTO:
# Ship yis whary talt.
#
# JEFFREY:
# Gig the ust got razy gibboars  know
# epoch: 17/50, batch: 200/616, loss: 53.920321021880554, avg loss: 54.11129019553344
# OVEUR:I see.  What do you think our alternatives are?
#
# It yevelf y.  polnimpire a. Eves ralk ouching come kney love. Lrigna menn you throy, mothing hidr.
#
# RIMMY:
# I can?
#
# BETTORETAY:
# You groliles.  Cau
# epoch: 17/50, batch: 300/616, loss: 49.54369660870938, avg loss: 52.121347751113824
# OVEUR:I see.  What do you think our alternatives are?
#
# HAN:
# That, who ly, you.
#
# DYOO n't ho lot yot's are.
#
# BHOHe Beopo, re the get you.
#
# FITHERISEND EF:
# Futsla. I'm  can't, agro?  The bal weppan chey
# epoch: 17/50, batch: 400/616, loss: 51.8284143581037, avg loss: 52.45101877662249
# OVEUR:I see.  What do you think our alternatives are?
#
# DYOS  It ther from rust thealo.  Net a dotter.
#
# WEESE:
# Lit's doing, it reot untilgere.  There, Uu gutsa have that?
#
# DUKE:
# Shis, ragett beporaldin
# epoch: 17/50, batch: 500/616, loss: 59.28385528989576, avg loss: 52.29242587211972
# OVEUR:I see.  What do you think our alternatives are?
#
# IA:
# Or. PRoge think Mrow us, macknt Bes in withe up see?
#
# MR. MARLHA:
# Alleaking trasper ake there afreecter us in trat my get muworect somafuldn'
# epoch: 17/50, batch: 600/616, loss: 44.465483910396024, avg loss: 53.87114788289067
# OVEUR:I see.  What do you think our alternatives are?
#
# SI BANDNANL I dosaused yeratroad opena time...
#
# RALLEUMA:
# About febugady nee there Came yout.
#
# CARSH:
# Nor't one, don't sobeno it're mmang!  Do yo
# epoch: 18/50, batch: 0/616, loss: 55.8006270445526, avg loss: 52.48420604924293
# OVEUR:I see.  What do you think our alternatives are?
#
# JESI SIND:
# Play?
#
# MO...ist. And halk dion the had, so hear al we to son.
#
# SENNT:
# Of loon wast there, sad a cort?
#
# JELLRESS:
# Yes.  I'm thear. What
# epoch: 18/50, batch: 100/616, loss: 50.98918470712914, avg loss: 50.8728175834432
# OVEUR:I see.  What do you think our alternatives are?
#
# DONNIE:
# Diken.  But a pars we'm lot tho Damads. She hougr and goysangat as have o place. sure you thy that's nother.  Goot and this has CKat peea
# epoch: 18/50, batch: 200/616, loss: 53.73963675100235, avg loss: 53.94037875361061
# OVEUR:I see.  What do you think our alternatives are?
#
# BETTY:
# Noth...frel snees you sonuper to eowirsmening is gurapper gail just have it at for that's I thinking wimmmero, ingn't out?
#
# RABET:
# I ciome
# epoch: 18/50, batch: 300/616, loss: 49.3575232958081, avg loss: 51.92647309222772
# OVEUR:I see.  What do you think our alternatives are?
#
# LEIA:
# Kan thif you could. Frobod. Aleen the thus. Proble you signing, is roing.
#
# HAN:
# The got is up of the to to tho adake aget was just car. He'
# epoch: 18/50, batch: 400/616, loss: 51.65832168210039, avg loss: 52.29509808722239
# OVEUR:I see.  What do you think our alternatives are?
#
# RECK:
# What's muvel.
#
# HAN:
# We'll then!
#
# FRESSERSE:
# Bert.  Your that frommew the harvond everyther as expointpets look ditic.
#
# RAISE:
# It you putta,
# epoch: 18/50, batch: 500/616, loss: 59.107457834645984, avg loss: 52.1452723816772
# OVEUR:I see.  What do you think our alternatives are?
#
# She goent a they I way fors kne's my fuckere.
#
# LUMAN:
# Trehorht. Chelp, alffing 't takt of must in his Mund. I to coce, Jest is mescer?
#
# FREDDY:
# J
# epoch: 18/50, batch: 600/616, loss: 44.312582636051516, avg loss: 53.70729908769689
# OVEUR:I see.  What do you think our alternatives are?
#
# SSOS:
# The sorhtave De right, tow frime a but in you tie before blay.
#
# SABONG I'll no figvisamicostent, I waut are mearded thingun I way digse boi
# epoch: 19/50, batch: 0/616, loss: 55.62092375614657, avg loss: 52.33134686981218
# OVEUR:I see.  What do you think our alternatives are?
#
# ADAM:
# Larefered rigire?
#
# LEELLER:
# Pelaths?
#
# SISTR:
# Aly he somen't I have incelt was Gurs, Leis a I araus gometh a jonfiss MAVELE:
# You sight's it?
# epoch: 19/50, batch: 100/616, loss: 50.847000335445315, avg loss: 50.70845196264969
# OVEUR:I see.  What do you think our alternatives are?
#
# DONNIE:
# rly dist.  what?
#
# KOVE:
# You dopleadat sither frounnt.
#
# JEFFREY:
# How wes ups that's a owly you for the in.
#
# DONNIE:
# They the and I know bu
# epoch: 19/50, batch: 200/616, loss: 53.5694088435616, avg loss: 53.78801431368484
# OVEUR:I see.  What do you think our alternatives are?
#
# DIGRY:
# You care aresn't one about you're eres if yit's s jifing mited.
#
# MAR:
# EN:
# I asst abunk RARETY:
# Thill Gur.
#
# Slose? Yes so talk we ta be did
# epoch: 19/50, batch: 300/616, loss: 49.1940343834249, avg loss: 51.74803628843079
# OVEUR:I see.  What do you think our alternatives are?
#
# MAN:
# White the so walkid ifol what ol eop. You have lothan a got been.!
#
# JIT FUREE:
# You.. N
# DON:
# Suse me haR it.
#
# PBARY:
# Ane.  I have thing the b
# epoch: 19/50, batch: 400/616, loss: 51.50398255747585, avg loss: 52.15460611363716
# OVEUR:I see.  What do you think our alternatives are?
#
# DWIEPTHR:
# Suckind patt onen rered a like and I I knowf to cant.
#
# REESKER:
# ERAER:
# You.
#
# RAESS:
# You don. . So they beasiartect onceadesulan.  us th
# epoch: 19/50, batch: 500/616, loss: 58.972625824967935, avg loss: 52.01018872522441
# OVEUR:I see.  What do you think our alternatives are?
#
# MR. PINK:
# Now.
#
# MEDD:
# Mr. They gampach on a bals?
#
# MIZA DON:
# You late awaning.
#
# ILDE:
# Hellin'. That litted the remom could afelight the don no in
# epoch: 19/50, batch: 600/616, loss: 44.170236112324886, avg loss: 53.5557970255966
# OVEUR:I see.  What do you think our alternatives are?
#
# PONNE:
# No, I don't knowndadding an! Where oveay, juule.
#
# MANDONI Ne?
#
# MONNA:
# They bap about about take we... leash, you world in's in is offard t
# epoch: 20/50, batch: 0/616, loss: 55.50029232975365, avg loss: 52.1935279996632
# OVEUR:I see.  What do you think our alternatives are?
#
# LELELLUR. Hes in it a, Let you another dy to dner stelly mine? They thites? I'm show.
#
# LOURA:
# :
# Yes. Not offep modes weet this derofe  so.
#
# BLARO
# epoch: 20/50, batch: 100/616, loss: 50.71267546295028, avg loss: 50.555541762241745
# OVEUR:I see.  What do you think our alternatives are?
#
# AVEIN:
# :
# Nolel.
#
# JECFEWIIMEN:
# I knows. dricat to thrives just hand quizy ecere my? This?
#
# KENGIE:
# That's dit the on. ake slight....
#
# GON:
# I lare
# epoch: 20/50, batch: 200/616, loss: 53.40668034707204, avg loss: 53.64473280151356
# OVEUR:I see.  What do you think our alternatives are?
#
# WONCCE Y:
# Non you turmny it's neekb You you did you're and Cn's the prom of a duys day... with a dest greaur fiR.BERT:
# And come unting it meyand
# epoch: 20/50, batch: 300/616, loss: 49.065908712281725, avg loss: 51.58990309128479
# OVEUR:I see.  What do you think our alternatives are?
#
#
# IVERIE:
# all tille and my topetty the see all  know that's Gurne.
#
# HAWEITOR:
# Where a from the houte is up look.
#
# BETRY:
# I all in Luken want. Tho
# epoch: 20/50, batch: 400/616, loss: 51.36075613750116, avg loss: 52.02886011962518
# OVEUR:I see.  What do you think our alternatives are?
#
# SAINE:
# Your for Radi...
#
# ARAMES:
# You don't lint some the have loughron..
#
# REEve he tot anytey pearou will beft and you see nookidy were sair Stri
# epoch: 20/50, batch: 500/616, loss: 58.85690366728644, avg loss: 51.880617522522776
# OVEUR:I see.  What do you think our alternatives are?
#
# BANNI:
# I'm beer trand Frscacked a foruh, you get if the!
#
# MR. WHIND:
# But a pars and you I have bllch the neepring we hake shour you got. Mnen are
# epoch: 20/50, batch: 600/616, loss: 44.03322557478584, avg loss: 53.411962983439466
# OVEUR:I see.  What do you think our alternatives are?
#
# MANDON:
# That t'ink aleh, OUt I want is. I thisnecies hay surryous a preally chifod dill. Tell fothan agroun beve sthaton is.
#
# DONNA:
# Yes, I'll fa
# epoch: 21/50, batch: 0/616, loss: 57.36891846871684, avg loss: 52.26213695740188
# OVEUR:I see.  What do you think our alternatives are?
#
# DELEAE:
# Who almondy this like askin of arennes.
#
# LAMANY:
# I hand wask thone sonels.
#
# LOURA:
# That with is your kinds wass hell thid scelving tandin
# epoch: 21/50, batch: 100/616, loss: 50.61415479542497, avg loss: 50.433879265049356
# OVEUR:I see.  What do you think our alternatives are?
#
# DO.. LEank to I can is oifor, broo the happeaspding are me you he's toul... sod to str, told alG Doning, They our no gelver you noce o that.  Yes
# epoch: 21/50, batch: 200/616, loss: 53.17936688568283, avg loss: 53.51834207351023
# OVEUR:I see.  What do you think our alternatives are?
#
# ELLICK:
# Dount whate have thestive bbur every strid leadd.
#
# BITE:
# You'll a shaty the can the dids all tint wholl you neaar Bribb?
#
# RETA:
# It's I ca
# epoch: 21/50, batch: 300/616, loss: 48.96737071580087, avg loss: 51.452498979526254
# OVEUR:I see.  What do you think our alternatives are?
#
# MRYSON:
# Hey beifes. by, andint, tralon't shere bange an at Afforugidn't tll bissen ... I'm that Fall is...? We wo's crank.
#
# REIK:
# Anay commen's t
# epoch: 21/50, batch: 400/616, loss: 51.25371879030146, avg loss: 51.91872977244864
# OVEUR:I see.  What do you think our alternatives are?
#
# SEOR:
# WOE:
# We're dopise youm, win worra creet shoterry mover venby you pomange. Stall... think, deeent.  Exmatt thind stanly tith for the beint?
# epoch: 21/50, batch: 500/616, loss: 58.68813303511651, avg loss: 51.75322712257228
# OVEUR:I see.  What do you think our alternatives are?
#
# RICH:
# If aldn't can't off you're wint wite mysnee.  Why ke orers. Hulditon is slopt you, any mistir. I just harknindever only your heruady ke jus
# epoch: 21/50, batch: 600/616, loss: 43.88936759819174, avg loss: 53.2725228115299
# OVEUR:I see.  What do you think our alternatives are?
#
# SAODON:
# ELAUROUCH:
# Yes. Ankin' ona was will all you?
#
# SOTEONN:
# As this should durwher you to eet tid hion the waspean a hay. Whatwoctonis. ..
#
# LA
# epoch: 22/50, batch: 0/616, loss: 56.972590890866925, avg loss: 52.118102290273505
# OVEUR:I see.  What do you think our alternatives are?
#
# PRIGHA:
# Why y you yen you deanalu'm sail tond deffrieple is wit's I dene. We must, there's cheon't and What're about, han gikguralfo?
#
# MS...
#
# ELA
# epoch: 22/50, batch: 100/616, loss: 50.84716009887578, avg loss: 51.49695037247601
# OVEUR:I see.  What do you think our alternatives are?
#
# DENNIE:
# Not reclobledy?
#
# SANDY:
# I known.
#
# DONN.
#
# CRCKEHN:
# Loo? When the big oused there want thromal. Ind.
#
# DONNIE:
# What shif lad some this bas t
# epoch: 22/50, batch: 200/616, loss: 53.06764458574823, avg loss: 53.879010615273586
# OVEUR:I see.  What do you think our alternatives are?
#
# BENTH:
# It in hall anyided mowry you quhr be here what's eally.
#
# BELTY:
# I've and fith He in, you veay.
#
# DICOCK:
# There's gean at day...
#
# REDAThinet
# epoch: 22/50, batch: 300/616, loss: 48.92754559232049, avg loss: 51.493771670190014
# OVEUR:I see.  What do you think our alternatives are?
#
# HIN:
# Let's comalllel the retcry let thire's the jose ond hand you're bld to y.
#
# LEIACK:
# What and in teld why was can be goted.
#
# HAN:
# It's it badd
# epoch: 22/50, batch: 400/616, loss: 51.242500522559986, avg loss: 51.917721856524764
# OVEUR:I see.  What do you think our alternatives are?
#
# DOE:
# YiRAE:
# I, fut the sust is of lop is to cast nower puert courees just conelt?  Susny finy might?
#
# SANLEy this you get a beor Froonk?
#
# REESE:
#
# epoch: 22/50, batch: 500/616, loss: 58.81731749877247, avg loss: 51.73350412806048
# OVEUR:I see.  What do you think our alternatives are?
#
# ROSPER:
# Bit is Me. Beaw, a therde. Yit's streidon jott is take for dowhink.
#
# MOTE:
# Mear.
#
# MR. NLLUMAN:
# Thanter, here rightess we mease, him right
# epoch: 22/50, batch: 600/616, loss: 43.76515279464993, avg loss: 53.18447232746878
# OVEUR:I see.  What do you think our alternatives are?
#
# STRANDOED:
# If I with I rearuuce dardate hat the seathayblie it!
#
# LOSTONZARN HNYRY:
# I think rear the rarcond Loknote, do eeade any is ded lundaft
# epoch: 23/50, batch: 0/616, loss: 55.91538565571486, avg loss: 51.93751942208411
# OVEUR:I see.  What do you think our alternatives are?
#
# PADDY:
# Oh, strot him wart?
#
# LEELER..
#
# CHE:
# Lathe you do you e.
#
# LAURA:
# I knoy...
#
# LESAN:
# Murs freak outenn't hos Ad not doing youm. Soraisedn't l
# epoch: 23/50, batch: 100/616, loss: 50.487841912182546, avg loss: 50.24539624693635
# OVEUR:I see.  What do you think our alternatives are?
#
# DR.. WHINK:
# IVE IKEOGOOF:
# Craem... with serding, carbing eile if syes. AEDY:
# This thank can muss compacesty would scanquise. I could they you goo
# epoch: 23/50, batch: 200/616, loss: 52.98614266503693, avg loss: 53.3142054313054
# OVEUR:I see.  What do you think our alternatives are?
#
# RITO:
# Tod like that's call hat beeat.
#
# EEM:
# Why. Heherc kide. . LANN:
# These diens now but I leilecilitinst there of wish unlishou, evenow  not in
# epoch: 23/50, batch: 300/616, loss: 48.83847663400108, avg loss: 51.252678587572944
# OVEUR:I see.  What do you think our alternatives are?
#
# DEDY:
# Wh' myings... and, weso. I think littll hat douns nothip back ese aught the aloing work I'cl got you litt of aton. You was gxAs onty To agm
# epoch: 23/50, batch: 400/616, loss: 51.016025454546785, avg loss: 51.74737282788085
# OVEUR:I see.  What do you think our alternatives are?
#
# ARG ENSE:
# You min.  himp dy it to cuits asy nad..
#
# ARD:
# Evat shouldn't sack Aroubrety on.
#
# LUKE:
# Andom.  It's very.
#
# SARACKAR:
# Yes. But sight?
#
# B
# epoch: 23/50, batch: 500/616, loss: 58.740536417436005, avg loss: 51.59966558086602
# OVEUR:I see.  What do you think our alternatives are?
#
# SILDIMEN:
# Not a taMr. That.
#
# CICK:
# What I know are and has is throw what's and wrere's ouher.
#
# MR. WHITE:
# Lut it's Ma, ener afrute dien thor leve
# epoch: 23/50, batch: 600/616, loss: 43.67320070325463, avg loss: 53.04241073817809
# OVEUR:I see.  What do you think our alternatives are?
#
# DENNA:
# Red Kagay know you ples, you seright juen can thone?
#
# LUG Why gues? I'm is Don, I have dab, A and caur stantil, but than. What who lonat g
# epoch: 24/50, batch: 0/616, loss: 55.75285389315853, avg loss: 51.826118180564066
# OVEUR:I see.  What do you think our alternatives are?
#
# SAPAN:
# Jutt surst.
#
# CUNS:
# You knore she a gete this heval goin't losar, and right on will got hearm.. Ice it.
#
# LAURA:
# Aneo goncending simmane I m
# epoch: 24/50, batch: 100/616, loss: 50.322583010002745, avg loss: 50.07940688484511
# OVEUR:I see.  What do you think our alternatives are?
#
# That's bays... fachan's des?
# .. broy.
#
# DONNIE:
# Ohing I've will chan hapneaty?
#
# SSOMON:
# I menne. Loy gotshea, you  Uut hewhered purspens.
#
# DOB Sub
# epoch: 24/50, batch: 200/616, loss: 52.86918992805433, avg loss: 53.16952219651146
# OVEUR:I see.  What do you think our alternatives are?
#
# PEROT:
# Tang pelit.. But your the peaveets.  I'm. It shotherse mice what Could. Yeaure?
#
# DEMMO:
# Yeesty, bla would, roy littlit it were.
#
# JOONZOROS
# epoch: 24/50, batch: 300/616, loss: 48.75032639395057, avg loss: 51.12291834624601
# OVEUR:I see.  What do you think our alternatives are?
#
# SARAWEY:
# R hood, you all up.
#
# WING:
# I can't no thing wey on, but my her?..rewheres ol meetven packind in ba heack tirk a ceacs. Tophing. All to a
# epoch: 24/50, batch: 400/616, loss: 50.88953002113815, avg loss: 51.640610427984086
# OVEUR:I see.  What do you think our alternatives are?
#
# RE:
# What pignofess get thy lase us was cast.
#
# SAROH:
# That of a lat not co beat tern gicSe's walkioke were stom. . Juck to?
# JRE:
# Not there.  Restu
# epoch: 24/50, batch: 500/616, loss: 58.620100643474146, avg loss: 51.49534479707164
# OVEUR:I see.  What do you think our alternatives are?
#
# MR. WHITP:
# Roulichicto, He for was day dalls tref lock ih, I haster aran's on the dave frung as us?
#
# GONNI:
# I don't bund.
#
# ROGX:
# What saritinetic
# epoch: 24/50, batch: 600/616, loss: 43.56940383397291, avg loss: 52.92535096680473
# OVEUR:I see.  What do you think our alternatives are?
#
# Svean'STA:
# Don. Yes, We hoped.
#
# DESMOND:
# The o crobled be about I lite you I war. I thust sis sne you ove prownee, down, are he do I dirkin. Is a
# epoch: 25/50, batch: 0/616, loss: 55.566121118299414, avg loss: 51.722272088869104
# OVEUR:I see.  What do you think our alternatives are?
#
# LELANS:
# A to wanneing and shours and leters aswicar Kim.
#
# JOFESE:
# What hit. Leave?
#
# BIt twora tome goin't totathrom Liveren manett when that aman
# ...
#
# EVERENGER:
# Yeads... Don't go noy wotere you goory could ingal.
#
# HAN:
# Little so d
# epoch: 42/50, batch: 100/616, loss: 49.28025806204464, avg loss: 48.64793054632962
# OVEUR:I see.  What do you think our alternatives are?
#
# TRUMAN:
# You awan!
# TERMINGTY:
# No. It's hajed all that that's to mifforen is Noy you new thated yon exmembely to love it.
#
# DONNIE:
# Oh, belient to
# epoch: 42/50, batch: 200/616, loss: 51.16783985811191, avg loss: 51.61983876936578
# OVEUR:I see.  What do you think our alternatives are?
#
# HET nowning.. I luck.  What's e it is bring the mathin't's it an tosel?
#
# PAON:
# Tould istor chen ablam crearutlrize cwent asu wreaing of he good..
# epoch: 42/50, batch: 300/616, loss: 47.888548506868844, avg loss: 49.872160954111386
# OVEUR:I see.  What do you think our alternatives are?
#
# BRAN:
# The  . . withle good, shings 1980 the houghin' MRYOPBEN:
# Whe do to deration you hum!
#
# PUDER:
# Heeredoul over of so.
#
# SHO we cadous.
#
# THRI ST
# epoch: 42/50, batch: 400/616, loss: 49.410535220031726, avg loss: 50.41292158773415
# OVEUR:I see.  What do you think our alternatives are?
#
# ALER:
# Soochen so.
#
# YODA:
# There.  one of I wespent you kilsing. Thusn't home not.  Come smean the vida. I my you're to what me at thankare s Read!
# epoch: 42/50, batch: 500/616, loss: 56.59189941374893, avg loss: 50.22475203599731
# OVEUR:I see.  What do you think our alternatives are?
#
# MR. WHITE:
# Mim you mive wance suse have this seques, sure. Light!..
#
# MOVE:
# Are I feect a bedy a conste let them. That's me? What's arly. Is's tha
# epoch: 42/50, batch: 600/616, loss: 42.37948527869709, avg loss: 51.551182100284585
# OVEUR:I see.  What do you think our alternatives are?
#
# DOSTAWA:
# It's Nel. Kit is forgsakes.
#
# MANR:
# I sagh they? The COUDDATLEY:
# Where.
#
# LAURA:
# A matta sige.  onathing not bet my min' like!
#
# NO. DANDY:
# epoch: 43/50, batch: 0/616, loss: 53.79142957280403, avg loss: 50.395312587630244
# OVEUR:I see.  What do you think our alternatives are?
#
# CEDFRET MEN:
# That? Well cimal.
#
# LELAND:
# I knight?
#
# JASE:
# Leare do joobe yer Heaillmonds JEding in ming I do you? BUNG Stop hell lore.
# PADD:
# He c
# epoch: 43/50, batch: 100/616, loss: 49.2429040795052, avg loss: 48.59894712730912
# OVEUR:I see.  What do you think our alternatives are?
#
# JEFFREY:
# Aco and right man a play, around a uped are Som this the dang of the over yes? Same afuatling I with you pather to still to expland. I h
# epoch: 43/50, batch: 200/616, loss: 51.103917289480705, avg loss: 51.55677327489069
# OVEUR:I see.  What do you think our alternatives are?
#
# BETTERMANE:
# We thare. I dreapliou doynce tat adesure untill and it's everyed that one ann in the diddialbain that the mowiresta think being downt
# epoch: 43/50, batch: 300/616, loss: 47.8605432588623, avg loss: 49.82707333478679
# OVEUR:I see.  What do you think our alternatives are?
#
# EODY:
# Al left long to here s sobernassesis olly carough.
#
# LUKE:
# Eree that wantm.ing all seder expling is Thin?
#
# DACKA HORLEN:
# I'm ald une thing,
# epoch: 43/50, batch: 400/616, loss: 49.370023960690084, avg loss: 50.36904780384158
# OVEUR:I see.  What do you think our alternatives are?
#
# LEIA:
# Orederbody sheat lose you bace.
#
# THAR:
# The weat.
#
# LEIA:
# Me.
#
# RIEE:
# Adighted Now Sed.  forte. Vere wither.
#
# DA:
# Et, no heam, they bant.
#
# REE
# epoch: 43/50, batch: 500/616, loss: 56.50474303489046, avg loss: 50.17898196806786
# OVEUR:I see.  What do you think our alternatives are?
#
# MR. WHIRE:
# Iffuchory. Bein thol Prove drong of for.
#
# MON:
# Tharking in fixugheat me?
#
# LEDAN:
# That's a lays.  whe ttalp onetchud one igheverate. Wh
# epoch: 43/50, batch: 600/616, loss: 42.338702178234996, avg loss: 51.49442427722933
# OVEUR:I see.  What do you think our alternatives are?
#
# TECMANNA:
# Well the there.
#
# DONNA:
# So whative simmatid?
#
# DELMARL:
# And the fucked I'm going You get?
#
# TOAULAN Lorce. They're.. Onith is he it do ke
# epoch: 44/50, batch: 0/616, loss: 53.584301188672924, avg loss: 50.32345183186777
# OVEUR:I see.  What do you think our alternatives are?
#
# LOURA:
# Als toog a do you thear thew, chaice're mist like. 're about a fin I take I back what here soperaytunather its appoteth much bited it in o
# epoch: 44/50, batch: 100/616, loss: 49.209620725485784, avg loss: 48.55361343505101
# OVEUR:I see.  What do you think our alternatives are?
#
# DONNIE:
# Suman. Would our, bory will sie in on calck.
#
# DONGANBESTORN:
# It's tell were porit?
#
# JEFFREY:
# Dally my it but hat awdys me vookbing what S
# epoch: 44/50, batch: 200/616, loss: 51.0479572778879, avg loss: 51.49667958236642
# OVEUR:I see.  What do you think our alternatives are?
#
# MAR:
# That'f think romase. Hown.
#
# BETTY:
# So didn't killar?
#
# BETTY:
# I have bodays of I heffen't was me away, I carfere's oneredio of eas, you're mi
# epoch: 44/50, batch: 300/616, loss: 47.83455837226449, avg loss: 49.78372703177857
# OVEUR:I see.  What do you think our alternatives are?
#
# PROFESSOR:
# Yeah, Or. You thing.. chaie course. NoLIE:
# You'a the here, too ba?  where's now. that this... Hen back...
#
# THREEPIO:
# The arourderonaig
# epoch: 44/50, batch: 400/616, loss: 49.33259406783965, avg loss: 50.32618116117426
# OVEUR:I see.  What do you think our alternatives are?
#
# THREER:
# I'm reasper night in cheat all your sted fast out munt to re.
#
# SARAH:
# You gor longer ne chat?  Rig.  It's me ut pean's ableck...
#
# PRiggge
# epoch: 44/50, batch: 500/616, loss: 56.415781037616036, avg loss: 50.133468956588345
# OVEUR:I see.  What do you think our alternatives are?
#
# THEROW:
# Bas a san here.  Heyway.
#
# REOFXRINE:
# But str eneshaippen is'd miffing frunty just this just like and what it sormin.
#
# LEEROR:
# As, shir, c
# epoch: 44/50, batch: 600/616, loss: 42.29962803467608, avg loss: 51.43985293444811
# OVEUR:I see.  What do you think our alternatives are?
#
# LEART:
# Than?
#
# DE don't grena shit, the feeen, two LANDA:
# Whering, then me leadly, The figss  'd... Ave do Led sistared telm know. Lilet expirlisa
# epoch: 45/50, batch: 0/616, loss: 53.54101888186798, avg loss: 50.269637642499234
# OVEUR:I see.  What do you think our alternatives are?
#
# LEERNn be hour fuckninetter. I'll slommstrionat? Andion't beind at maning to the we up one ok... Bls my don't otherour my palery awriver highule
# epoch: 45/50, batch: 100/616, loss: 49.17123945430133, avg loss: 48.510256936833905
# OVEUR:I see.  What do you think our alternatives are?
#
# DONNIE:
# It's a metwiled up?
#
# CHER:
# Neaipested roy.
#
# GRETCHEN:
# Holls but love?..toppor, Do darty. I what gsioe.
#
# FRANK:
# I crock say?
#
# DENNY:
# I nig
# epoch: 45/50, batch: 200/616, loss: 50.99012039810778, avg loss: 51.44174320189442
# OVEUR:I see.  What do you think our alternatives are?
#
# JOMMY:
# Twemptoow a Rdank, of a long plys it?
#
# IO:
# Hole of they not letivouels ... our ciulded!
#
# CHRIMAN:
# Dona here.
#
# DOT:
# Mane.  Youns.
#
# TER:
# Mal
# epoch: 45/50, batch: 300/616, loss: 47.81224267467245, avg loss: 49.74141611740183
# OVEUR:I see.  What do you think our alternatives are?
#
# LUKE:
# Fudn happener like, miffanghor.
#
# LANNE:
# It's get miston't you, skill. . Gut t would sto Con't that, to donstell runt get the tick again thi
# epoch: 45/50, batch: 400/616, loss: 49.29863117674087, avg loss: 50.28516203929343
# OVEUR:I see.  What do you think our alternatives are?
#
# CLEWE:
# Hotns the have it you.. Moplly aread is madatitichent. I thow me.  Shers were caperading won't?
#
# MAN:
# They don't fucking plave is hin stro
# epoch: 45/50, batch: 500/616, loss: 56.32037617823481, avg loss: 50.087518902032
# OVEUR:I see.  What do you think our alternatives are?
#
# DREDDY:
# Nut wherment? It I can got off the Mistit off me.
#
# MR. PINK:
# Yee.  Bllike on you matere beir.  just cusple. You wontren that the michort,
# epoch: 45/50, batch: 600/616, loss: 42.2634000103219, avg loss: 51.38658423172426
# OVEUR:I see.  What do you think our alternatives are?
#
# LAURE:
# To the gir away an MACHATP:
# There an is.
#
# LETEY:
# Nob. That's can't gut! What me us goics Mo sery bade some like Surdy, Delf but a miluty k
# epoch: 46/50, batch: 0/616, loss: 53.46649296470984, avg loss: 50.21372743313106
# OVEUR:I see.  What do you think our alternatives are?
#
# SAUEN:
# Forunt persa get's never end couldn't's to halp it. Hellass with that hee, Donnourcar I don't sholdn't work.!
#
# JOH:
# Here that think I fart
# epoch: 46/50, batch: 100/616, loss: 49.141862748025964, avg loss: 48.467292876781016
# OVEUR:I see.  What do you think our alternatives are?
#
# TRUMAN:
# You shey missipe.
#
# DONNIE:
# I've be peaytsic on theeating keel theithh then in a beipped fly this is a Shinks, then.
#
# MR. THIEDOX:
# Now to
# epoch: 46/50, batch: 200/616, loss: 50.94337076175561, avg loss: 51.38481037171108
# OVEUR:I see.  What do you think our alternatives are?
#
# EVERET you? I can here cteel. He's gonor just in penss. I've to do you ciondy me kill miccall wint this?
#
# DOT:
# I can me dict.  Sime man shit. I k
# epoch: 46/50, batch: 300/616, loss: 47.78875018289422, avg loss: 49.70035332362349
# OVEUR:I see.  What do you think our alternatives are?
#
# HAN:
# You get?
#
# JEFFREY:
# Do be fuhar, EVARE:
# Yes my. Welp to the beed the dred a lot your ngstrowore, My onntem, thankeven. That me, RLEE SAWEIS.
# epoch: 46/50, batch: 400/616, loss: 49.26681983315153, avg loss: 50.24613581751522
# OVEUR:I see.  What do you think our alternatives are?
#
# PREERER:
# Are tell Shated if theilling.
#
# LEIA:
# Sonityle feute the dity shole thorefity, losagerone helve the inny... the have there?  Nown.
#
# CIN:
#
# epoch: 46/50, batch: 500/616, loss: 56.23014241111081, avg loss: 50.0431204057832
# OVEUR:I see.  What do you think our alternatives are?
#
# RONN:
# I fisbeed go you, bat meack aclecause or at to fcom spayssiss no stacrle.
#
# MR. PINK:
# Rougre itst?
#
# MIVEDDIE:
# I can ones kneer was the think
# epoch: 46/50, batch: 600/616, loss: 42.22668568569313, avg loss: 51.33542333887109
# OVEUR:I see.  What do you think our alternatives are?
#
# CLALLILEY:
# Lowin'. .
#
# ENDENKAVE JAY:
# Donce the beer the well fero grant, Proure alf that shit now dase beard. We gett and batchert thour fint, I
# epoch: 47/50, batch: 0/616, loss: 53.38234784905538, avg loss: 50.15791761508717
# OVEUR:I see.  What do you think our alternatives are?
#
# JEFFFREEST:
# Well has with I have rus and yet the work it the whoce. Lut everid Ling a restato cast in her were that's her.
#
# ELANKE:
# Leth in anywa
# epoch: 47/50, batch: 100/616, loss: 49.11077397383225, avg loss: 48.422616360134406
# OVEUR:I see.  What do you think our alternatives are?
#
# DONNIE:
# The stey wit a do never you...
#
# DONNIE:
# Why pe iss to sive verion.
#
# JOFFRQ8E:
# Wimalment out? So so targe... woovery... what to human surp
# epoch: 47/50, batch: 200/616, loss: 50.897199758940786, avg loss: 51.33036606601357
# OVEUR:I see.  What do you think our alternatives are?
#
# SOL MR...
#
# BERTY:
# Why lefe thant that call what Deastan, ARIE:
# I sacs.
#
# BE.. Whink a fucknirent, I ple witm.
#
# LICH:
# Trome it.
#
# BETTY:
# I are tilan
# epoch: 47/50, batch: 300/616, loss: 47.765730782900924, avg loss: 49.65962547153633
# OVEUR:I see.  What do you think our alternatives are?
#
# FULLUROY:
# Don't trase... What's do you?
#
# MEDDR:
# Good kilpive take there this tell ato book s give ever you so onton't this oldyor I serouek Some
# epoch: 47/50, batch: 400/616, loss: 49.235964434677086, avg loss: 50.20867808746482
# OVEUR:I see.  What do you think our alternatives are?
#
# CANDY:
# Sees with the not to astow, HA if mh yourst.
#
# LEIA:
# An be helr, broke let you the. Angencus.
#
# SIGH:
# Yes, like it hurvy, guing.  You go com
# epoch: 47/50, batch: 500/616, loss: 56.14202255751227, avg loss: 49.99948470776654
# OVEUR:I see.  What do you think our alternatives are?
#
# JET:
# Ret No for skindals but I been.
#
# MR, I fouikingine fadema Baray.
#
# VINE:
# Ick, it stalck the girt jaited is too... I can should tulso, you're
# epoch: 47/50, batch: 600/616, loss: 42.18978754123054, avg loss: 51.286112599835874
# OVEUR:I see.  What do you think our alternatives are?
#
# SANDON:
# Ot unty y I want to was afro!
#
# LAURAN HANTAG, it has you barrictuad, out you.
#
# STANGE:
# You want bre.
#
# LAURA:
# You going of I'm get you mes
# epoch: 48/50, batch: 0/616, loss: 53.285322090721536, avg loss: 50.102637130156154
# OVEUR:I see.  What do you think our alternatives are?
#
# DEDDYST JEFF2RE:
# Your expe. the e'm ask ea goding collle anZA   Out vistard...
#
# LEEL:
#
# YODDY:
# A go your tight?
#
# EDEY:
# Sisother just gonna knot re
# epoch: 48/50, batch: 100/616, loss: 49.073620403329684, avg loss: 48.37731242333264
# OVEUR:I see.  What do you think our alternatives are?
#
# DR. BEANKO:
# How in I'd cord.
#
# CODESTORNGEO:
# I knore? Anvis? What a finl. sumathereallspitund Whole?
#
# DONNIE:
# Donnling?
#
# DY.. LIMEN:
# No in the wec
# epoch: 48/50, batch: 200/616, loss: 50.85834572900576, avg loss: 51.278459224292504
# OVEUR:I see.  What do you think our alternatives are?
#
# ELAMPR:
# Year.
#
# ADDY:
# Are have eatagh!
#
# TER:
# I'm soushered a Mids?
#
# BETTY:
# Care of beeray lersably.
#
# CORTY:
# Yes, cart.
#
# BET:
# Thind him.  Wher len'
# epoch: 48/50, batch: 300/616, loss: 47.74458376481361, avg loss: 49.61934600172198
# OVEUR:I see.  What do you think our alternatives are?
#
# CANDR:
# What fet of am ouput pret.  plase start fucking, I gryon try himpora anyw the fientrroury our na cart id or. is cand is you micer.  neep t
# epoch: 48/50, batch: 400/616, loss: 49.20501622708032, avg loss: 50.17257266957015
# OVEUR:I see.  What do you think our alternatives are?
#
# HAN:
# Mem.  Came and you...
#
# SARAH:
# Wadee in?
#
# LEIA:
# I don't the be ctoulds all right you, gonnank tell so but ow with it you peoral?
#
# REESE:
# I kn
# epoch: 48/50, batch: 500/616, loss: 56.054389857127944, avg loss: 49.95650142276285
# OVEUR:I see.  What do you think our alternatives are?
#
# MR. THURMANK:
# That's shouth fuck. . agoone?
#
# MR. IN. Ove Me, Mund!.. t a finy carfficining you, check. Mun, had be, you're bet'le could like sown
# epoch: 48/50, batch: 600/616, loss: 42.15379705781217, avg loss: 51.23909642619609
# OVEUR:I see.  What do you think our alternatives are?
#
# MANNOS:
# Well?
#
# MAN:
# A that hurve will's lane., dreid, they light.
#
# DAN:
# I don't wraie werlud. They're don't bethe it, were pumbarit coming that n
# epoch: 49/50, batch: 0/616, loss: 53.2146284400572, avg loss: 50.0520573988215
# OVEUR:I see.  What do you think our alternatives are?
#
# LTEREST:
# The thiguids right. I goor, this offie who string this worcond your frookeforaurt up a from wot's wrone for are to eet We tell planiin..
# epoch: 49/50, batch: 100/616, loss: 49.03420366227626, avg loss: 48.331754285657034
# OVEUR:I see.  What do you think our alternatives are?
#
# BETTY:
# Sto do. Now help hever's yeall. You Tell they wake we get arc...real Bagkse her sad envines ig a dotyou wantsound guy?
#
# DENNY:
# Samaty.
#
# JE
# epoch: 49/50, batch: 200/616, loss: 50.82166815115289, avg loss: 51.22936699015649
# OVEUR:I see.  What do you think our alternatives are?
#
# BETTY:
# To panes Morrouse?
#
# CHRICK:
# You pay about. You'd you?
#
# TEGIN:
# Yound home someion. You can I'm calledy a did are that.
#
# EDDY:
# No, Butn come
# epoch: 49/50, batch: 300/616, loss: 47.725337238129946, avg loss: 49.578274982913385
# OVEUR:I see.  What do you think our alternatives are?
#
# DWIGHT:
# Helpink this mist come botthe you. Thooe hone shiouen away anyway briventing and neenning tiey was battening the be tthe will the picrer
# epoch: 49/50, batch: 400/616, loss: 49.17626326741109, avg loss: 50.13782990703298
# OVEUR:I see.  What do you think our alternatives are?
#
# SARAH:
# I'll I as eever. I could?
#
# RUKE:
# So so, cirringin. Druth him.
#
# DECKARD:
# Antoright lot there!
#
# VIPER:
# That'S JERREAN:
# Noo.
#
# REESE:
# We're go
# epoch: 49/50, batch: 500/616, loss: 55.964791948875344, avg loss: 49.91373776885634
# OVEUR:I see.  What do you think our alternatives are?
#
# MR..
# CORICE:
# You recibody got you're, NIN.Tres doetione to are justich mated Mo. Yase won't breed very all on the dig, you me a sime, like deatip
# epoch: 49/50, batch: 600/616, loss: 42.11895028026538, avg loss: 51.193876254642305
# OVEUR:I see.  What do you think our alternatives are?
#
# LOURLE MOND:
# Maddime you name reppsevele.
#
# BABBY:
# Maybe me in was munal to you sone bagwent?
#
# MAVERIVURON:
# No last to what was do?
#
# DONNIE:
# What'
# epoch: 50/50, batch: 0/616, loss: 53.23871187768993, avg loss: 50.0121007457631
# OVEUR:I see.  What do you think our alternatives are?
#
# LEELLA:
# I tatelime.
#
# FRAURA:
# Oh, somethere id?..
#
# RAHARD:
# Not.
#
# SARLIE:
# I comer, 'f wime to thing, ar. I at will that going tell the armorumby m
